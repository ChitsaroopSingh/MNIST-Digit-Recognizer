# %% [markdown]
# Fetching the MNIST Dataset

# %%
from sklearn.datasets import fetch_openml
import joblib
mnist = fetch_openml("mnist_784", as_frame=False)

# %% [markdown]
# Setting up the labels

# %%
X = mnist.data
y = mnist.target
print(X.shape) #there are total of 70,000 and each image has 28x28 = 784 pixels
print(y.shape) #total of 70,000 images so a unique number
# Out:
# (70000, 784)
# (70000,)

# %% [markdown]
# Training the SGD Classifier

# %%
from sklearn.linear_model import SGDClassifier
sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 from sklearn.linear_model import SGDClassifier
#       2 sgd_clf = SGDClassifier(random_state=42)
# ----> 3 sgd_clf.fit(X,y)
#       4 print(type(sgd_clf))
#
# File c:\Users\csing\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\csing\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:941, in BaseSGDClassifier.fit(self, X, y, coef_init, intercept_init, sample_weight)
#     912 """Fit linear model with Stochastic Gradient Descent.
#     913
#     914 Parameters
#    (...)    937     Returns an instance of self.
#     938 """
#     939 self._more_validate_params()
# --> 941 return self._fit(
#     942     X,
#     943     y,
#     944     alpha=self.alpha,
#     945     loss=self.loss,
#     946     learning_rate=self.learning_rate,
#     947     coef_init=coef_init,
#     948     intercept_init=intercept_init,
#     949     sample_weight=sample_weight,
#     950 )
#
# File c:\Users\csing\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:723, in BaseSGDClassifier._fit(self, X, y, alpha, loss, learning_rate, coef_init, intercept_init, sample_weight)
#     720 # Clear iteration count for multiple call to fit.
#     721 self.t_ = 1.0
# --> 723 self._partial_fit(
#     724     X,
#     725     y,
#     726     alpha,
#     727     loss,
#     728     learning_rate,
#     729     self.max_iter,
#     730     classes,
#     731     sample_weight,
#     732     coef_init,
#     733     intercept_init,
#     734 )
#     736 if (
#     737     self.tol is not None
#     738     and self.tol > -np.inf
#     739     and self.n_iter_ == self.max_iter
#     740 ):
#     741     warnings.warn(
#     742         (
#     743             "Maximum number of iteration reached before "
#    (...)    747         ConvergenceWarning,
#     748     )
#
# File c:\Users\csing\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:660, in BaseSGDClassifier._partial_fit(self, X, y, alpha, loss, learning_rate, max_iter, classes, sample_weight, coef_init, intercept_init)
#     658 # delegate to concrete training procedure
#     659 if n_classes > 2:
# --> 660     self._fit_multiclass(
#     661         X,
#     662         y,
#     663         alpha=alpha,
#     664         learning_rate=learning_rate,
#     665         sample_weight=sample_weight,
#     666         max_iter=max_iter,
#     667     )
#     668 elif n_classes == 2:
#     669     self._fit_binary(
#     670         X,
#     671         y,
#    (...)    675         max_iter=max_iter,
#     676     )
#
# File c:\Users\csing\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:809, in BaseSGDClassifier._fit_multiclass(self, X, y, alpha, learning_rate, sample_weight, max_iter)
#     807 random_state = check_random_state(self.random_state)
#     808 seeds = random_state.randint(MAX_INT, size=len(self.classes_))
# --> 809 result = Parallel(
#     810     n_jobs=self.n_jobs, verbose=self.verbose, require="sharedmem"
#     811 )(
#     812     delayed(fit_binary)(
#     813         self,
#     814         i,
#     815         X,
#     816         y,
#     817         alpha,
#     818         learning_rate,
#     819         max_iter,
#     820         self._expanded_class_weight[i],
#     821         1.0,
#     822         sample_weight,
#     823         validation_mask=validation_mask,
#     824         random_state=seed,
#     825     )
#     826     for i, seed in enumerate(seeds)
#     827 )
#     829 # take the maximum of n_iter_ over every binary fit
#     830 n_iter_ = 0.0
#
# File c:\Users\csing\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\csing\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\csing\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\csing\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File c:\Users\csing\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:478, in fit_binary(est, i, X, y, alpha, learning_rate, max_iter, pos_weight, neg_weight, sample_weight, validation_mask, random_state)
#     475 tol = est.tol if est.tol is not None else -np.inf
#     477 _plain_sgd = _get_plain_sgd_function(input_dtype=coef.dtype)
# --> 478 coef, intercept, average_coef, average_intercept, n_iter_ = _plain_sgd(
#     479     coef,
#     480     intercept,
#     481     average_coef,
#     482     average_intercept,
#     483     est._loss_function_,
#     484     penalty_type,
#     485     alpha,
#     486     est._get_l1_ratio(),
#     487     dataset,
#     488     validation_mask,
#     489     est.early_stopping,
#     490     validation_score_cb,
#     491     int(est.n_iter_no_change),
#     492     max_iter,
#     493     tol,
#     494     int(est.fit_intercept),
#     495     int(est.verbose),
#     496     int(est.shuffle),
#     497     seed,
#     498     pos_weight,
#     499     neg_weight,
#     500     learning_rate_type,
#     501     est.eta0,
#     502     est.power_t,
#     503     0,
#     504     est.t_,
#     505     intercept_decay,
#     506     est.average,
#     507 )
#     509 if est.average:
#     510     if len(est.classes_) == 2:
#
# KeyboardInterrupt:
