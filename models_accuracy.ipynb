# %% [markdown]
# Importing Libraries

# %%
import pickle
import joblib
import time
from sklearn.metrics import accuracy_score

# %% [markdown]
# Loading QMNIST Dataset

# %%
with open("dataset/qmnist.pkl", "rb") as f:
    qmnist = pickle.load(f)

X = qmnist["data"]
y = qmnist["labels"].ravel()

# Flatten 28x28 images into 784 features
X = X.reshape(-1, 28 * 28)
# Out:
# C:\Users\csing\AppData\Local\Temp\ipykernel_4860\3682511631.py:2: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   qmnist = pickle.load(f)

# %% [markdown]
# Loading Models

# %%
models = {
    "SGD": "models/sgd_model.joblib",
    "Decision Tree": "models/dt_model.joblib",
    "KNN": "models/knn_model.joblib",
}
